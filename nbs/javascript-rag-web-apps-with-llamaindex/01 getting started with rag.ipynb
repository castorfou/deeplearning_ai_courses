// %% [markdown]
// nice introduction video
//
// ![image.png](attachment:image.png)

// %% [markdown]
// mince tout est en javascript, en meme temps c'est dans le titre j'aurais pu m'en douter

// %% [markdown]
// j'installe le kernel deno (voir env/deno.txt)

// %%
import * as mod from "https://deno.land/std@0.213.0/dotenv/mod.ts";
const keys = await mod.load({export:true}) // read API key from .env

// %%
mod.load.toString()
// Out:
// 'async function load({ envPath = ".env", examplePath = ".env.example", defaultsPath = ".env.defaults", export: _export = false, allowEmptyValues = false } = {}) {\n' +
//   "  const conf = envPath ? await parseFile(envPath) : {};\n" +
//   "  if (defaultsPath) {\n" +
//   "    const confDefaults = await parseFile(defaultsPath);\n" +
//   "    for(const key in confDefaults){\n" +
//   "      if (!(key in conf)) {\n" +
//   "        conf[key] = confDefaults[key];\n" +
//   "      }\n" +
//   "    }\n" +
//   "  }\n" +
//   "  if (examplePath) {\n" +
//   "    const confExample = await parseFile(examplePath);\n" +
//   "    assertSafe(conf, confExample, allowEmptyValues);\n" +
//   "  }\n" +
//   "  if (_export) {\n" +
//   "    for(const key in conf){\n" +
//   "      if (Deno.env.get(key) !== undefined) continue;\n" +
//   "      Deno.env.set(key, conf[key]);\n" +
//   "    }\n" +
//   "  }\n" +
//   "  return conf;\n" +
//   "}"

// %%
keys
// Out:
// {}

// %%
import { 
    Document, 
    VectorStoreIndex, 
    SimpleDirectoryReader 
} from "npm:llamaindex@0.1.8"

// %%
const documents = await new SimpleDirectoryReader()
    .loadData({directoryPath: "../../data/javascript-rag-web-apps-with-llamaindex/"})

// %%
const index = await VectorStoreIndex.fromDocuments(documents)

// %%
const queryEngine = index.asQueryEngine()

// %%
const response = await queryEngine.query({
    query: "What did the author do in college?"
})
// Out:
// Stack trace:
// Error: 503 <html>
// <head>
// <title>Application Blocked</title>
// <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
// <META HTTP-EQUIV="PRAGMA" CONTENT="NO-CACHE">
// <meta name="viewport" content="initial-scale=1.0">
// <style>
//   #content {
//     border:3px solid#aaa;
//     background-color:#fff;
//     margin:1.5em;
//     padding:1.5em;
//     font-family:Tahoma,Helvetica,Arial,sans-serif;
//     font-size:1em;
//   }
//   h1 {
//     font-size:1.3em;
//     font-weight:bold;
//     color:#196390;
//   }
//   b {
//     font-weight:normal;
//     color:#196390;
//   }
// </style>
// </head>
// <body bgcolor="#e7e8e9">
// <div id="content">
// <h1>MICHELIN GROUP - Application Blocked</h1>
// <p>Access to the application you were trying to use has been blocked in accordance with company policy. Please contact your system administrator if you believe this is in error.</p>
// <p><b>User:</b> f279814 </p>
// ...

// %%
console.log(response.toString())
